# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\USER PC\\dirty_data.csv')
df
# Out:
#     Rank   Peak All Time Peak     Actual gross Actual gross(in 2022 dollars)  \
# 0      1      1             2    $780,000,000                  $780,000,000
# 1      2      1          7[2]    $579,800,000                  $579,800,000
# 2      3   1[4]          2[5]    $411,000,000                  $560,622,615
# 3      4   2[7]         10[7]    $397,300,000                  $454,751,555
# 4      5   2[4]           NaN    $345,675,146                  $402,844,849
# 5      6   2[4]         10[9]    $305,158,363                  $388,978,496
# 6      7  2[10]           NaN    $280,000,000                  $381,932,682
# 7      7    NaN           NaN    $257,600,000                  $257,600,000
# 8      9    NaN           NaN    $256,084,556                  $312,258,401
# 9     10    NaN           NaN    $250,400,000                  $309,141,878
# 10    11    NaN           NaN  $229,100,000[b]                 $283,202,896
# ...

# %%
df['Peak'] = df['Peak'].str.replace(r'[\[\]]', '', regex=True)
df
# Out:
#     Rank Peak All Time Peak     Actual gross Actual gross(in 2022 dollars)  \
# 0      1    1             2    $780,000,000                  $780,000,000
# 1      2    1          7[2]    $579,800,000                  $579,800,000
# 2      3   14          2[5]    $411,000,000                  $560,622,615
# 3      4   27         10[7]    $397,300,000                  $454,751,555
# 4      5   24           NaN    $345,675,146                  $402,844,849
# 5      6   24         10[9]    $305,158,363                  $388,978,496
# 6      7  210           NaN    $280,000,000                  $381,932,682
# 7      7  NaN           NaN    $257,600,000                  $257,600,000
# 8      9  NaN           NaN    $256,084,556                  $312,258,401
# 9     10  NaN           NaN    $250,400,000                  $309,141,878
# 10    11  NaN           NaN  $229,100,000[b]                 $283,202,896
# 11    12  NaN        14[17]    $227,400,000                  $295,301,479
# ...

# %%
df['All Time Peak'] =df['All Time Peak'].str.replace(r'[\[\]]','', regex=True)
df
# Out:
#     Rank Peak All Time Peak     Actual gross Actual gross(in 2022 dollars)  \
# 0      1    1             2    $780,000,000                  $780,000,000
# 1      2    1            72    $579,800,000                  $579,800,000
# 2      3   14            25    $411,000,000                  $560,622,615
# 3      4   27           107    $397,300,000                  $454,751,555
# 4      5   24           NaN    $345,675,146                  $402,844,849
# 5      6   24           109    $305,158,363                  $388,978,496
# 6      7  210           NaN    $280,000,000                  $381,932,682
# 7      7  NaN           NaN    $257,600,000                  $257,600,000
# 8      9  NaN           NaN    $256,084,556                  $312,258,401
# 9     10  NaN           NaN    $250,400,000                  $309,141,878
# 10    11  NaN           NaN  $229,100,000[b]                 $283,202,896
# 11    12  NaN          1417    $227,400,000                  $295,301,479
# ...

# %%
df['Peak'].isnull().sum()
# Out:
# 11

# %%
df['Peak'].ffill()
# Out:
# 0       1
# 1       1
# 2      14
# 3      27
# 4      24
# 5      24
# 6     210
# 7     210
# 8     210
# 9     210
# 10    210
# 11    210
# 12    210
# 13    120
# 14     2c
# 15     2c
# 16     2c
# 17     2c
# 18     2c
# 19     2c
# Name: Peak, dtype: object

# %%
df['All Time Peak'].isnull().sum()
# Out:
# 14

# %%
df['All Time Peak'].bfill()
# Out:
# 0        2
# 1       72
# 2       25
# 3      107
# 4      109
# 5      109
# 6     1417
# 7     1417
# 8     1417
# 9     1417
# 10    1417
# 11    1417
# 12     NaN
# 13     NaN
# 14     NaN
# 15     NaN
# 16     NaN
# 17     NaN
# 18     NaN
# 19     NaN
# Name: All Time Peak, dtype: object

# %%
df['All Time Peak'].ffill()
# Out:
# 0        2
# 1       72
# 2       25
# 3      107
# 4      107
# 5      109
# 6      109
# 7      109
# 8      109
# 9      109
# 10     109
# 11    1417
# 12    1417
# 13    1417
# 14    1417
# 15    1417
# 16    1417
# 17    1417
# 18    1417
# 19    1417
# Name: All Time Peak, dtype: object

# %%
df['Actual gross'] =df['Actual gross'].str.replace(r'[$,]','', regex=True)
df
# Out:
#     Rank Peak All Time Peak  Actual gross Actual gross(in 2022 dollars)  \
# 0      1    1             2    780000000                  $780,000,000
# 1      2    1            72    579800000                  $579,800,000
# 2      3   14            25    411000000                  $560,622,615
# 3      4   27           107    397300000                  $454,751,555
# 4      5   24           NaN    345675146                  $402,844,849
# 5      6   24           109    305158363                  $388,978,496
# 6      7  210           NaN    280000000                  $381,932,682
# 7      7  NaN           NaN    257600000                  $257,600,000
# 8      9  NaN           NaN    256084556                  $312,258,401
# 9     10  NaN           NaN    250400000                  $309,141,878
# 10    11  NaN           NaN  229100000[b]                 $283,202,896
# 11    12  NaN          1417    227400000                  $295,301,479
# ...

# %%
df['Actual gross(in 2022 dollars)'] = df['Actual gross(in 2022 dollars)'].str.replace(r'[$,]','',regex=True)
df
# Out:
#     Rank Peak All Time Peak  Actual gross Actual gross(in 2022 dollars)  \
# 0      1    1             2    780000000                     780000000
# 1      2    1            72    579800000                     579800000
# 2      3   14            25    411000000                     560622615
# 3      4   27           107    397300000                     454751555
# 4      5   24           NaN    345675146                     402844849
# 5      6   24           109    305158363                     388978496
# 6      7  210           NaN    280000000                     381932682
# 7      7  NaN           NaN    257600000                     257600000
# 8      9  NaN           NaN    256084556                     312258401
# 9     10  NaN           NaN    250400000                     309141878
# 10    11  NaN           NaN  229100000[b]                    283202896
# 11    12  NaN          1417    227400000                     295301479
# ...

# %%
df['Tour title']
# Out:
# 0                              The Eras Tour †
# 1                       Renaissance World Tour
# 2                  Sticky & Sweet Tour ‡[4][a]
# 3                  Beautiful Trauma World Tour
# 4                      Reputation Stadium Tour
# 5                                The MDNA Tour
# 6                    Taking Chances World Tour
# 7                            Summer Carnival †
# 8                     The Formation World Tour
# 9                          The 1989 World Tour
# 10             The Mrs. Carter Show World Tour
# 11                     The Monster Ball Tour *
# 12                        Prismatic World Tour
# 13    Living Proof: The Farewell Tour ‡[21][a]
# 14                            Confessions Tour
# 15                   The Truth About Love Tour
# 16                          Born This Way Ball
# 17                            Rebel Heart Tour
# 18                             Adele Live 2016
# 19                                The Red Tour
# ...

# %%
# Keep only letters (remove numbers and special characters)
df['Tour title']=df['Tour title'].str.replace(r'[^A-Za-z\s]','',regex=True)
df
# Out:
#     Rank Peak All Time Peak  Actual gross Actual gross(in 2022 dollars)  \
# 0      1    1             2    780000000                     780000000
# 1      2    1            72    579800000                     579800000
# 2      3   14            25    411000000                     560622615
# 3      4   27           107    397300000                     454751555
# 4      5   24           NaN    345675146                     402844849
# 5      6   24           109    305158363                     388978496
# 6      7  210           NaN    280000000                     381932682
# 7      7  NaN           NaN    257600000                     257600000
# 8      9  NaN           NaN    256084556                     312258401
# 9     10  NaN           NaN    250400000                     309141878
# 10    11  NaN           NaN  229100000[b]                    283202896
# 11    12  NaN          1417    227400000                     295301479
# ...

# %%
df['Tour title']
# Out:
# 0                       The Eras Tour
# 1               Renaissance World Tour
# 2                 Sticky  Sweet Tour a
# 3          Beautiful Trauma World Tour
# 4              Reputation Stadium Tour
# 5                        The MDNA Tour
# 6            Taking Chances World Tour
# 7                     Summer Carnival
# 8             The Formation World Tour
# 9                      The  World Tour
# 10      The Mrs Carter Show World Tour
# 11              The Monster Ball Tour
# 12                Prismatic World Tour
# 13    Living Proof The Farewell Tour a
# 14                    Confessions Tour
# 15           The Truth About Love Tour
# 16                  Born This Way Ball
# 17                    Rebel Heart Tour
# 18                         Adele Live
# 19                        The Red Tour
# Name: Tour title, dtype: object

# %%
#7
df['Average gross'] = df['Average gross'].str.replace(r'[$,]','',regex=True)
df
# Out:
#     Rank Peak All Time Peak  Actual gross Actual gross(in 2022 dollars)  \
# 0      1    1             2    780000000                     780000000
# 1      2    1            72    579800000                     579800000
# 2      3   14            25    411000000                     560622615
# 3      4   27           107    397300000                     454751555
# 4      5   24           NaN    345675146                     402844849
# 5      6   24           109    305158363                     388978496
# 6      7  210           NaN    280000000                     381932682
# 7      7  NaN           NaN    257600000                     257600000
# 8      9  NaN           NaN    256084556                     312258401
# 9     10  NaN           NaN    250400000                     309141878
# 10    11  NaN           NaN  229100000[b]                    283202896
# 11    12  NaN          1417    227400000                     295301479
# ...

# %%
#8
df['Ref.'] = df['Ref.'].str.replace(r'[\[\]]','',regex=True)
df
# Out:
#     Rank Peak All Time Peak  Actual gross Actual gross(in 2022 dollars)  \
# 0      1    1             2    780000000                     780000000
# 1      2    1            72    579800000                     579800000
# 2      3   14            25    411000000                     560622615
# 3      4   27           107    397300000                     454751555
# 4      5   24           NaN    345675146                     402844849
# 5      6   24           109    305158363                     388978496
# 6      7  210           NaN    280000000                     381932682
# 7      7  NaN           NaN    257600000                     257600000
# 8      9  NaN           NaN    256084556                     312258401
# 9     10  NaN           NaN    250400000                     309141878
# 10    11  NaN           NaN  229100000[b]                    283202896
# 11    12  NaN          1417    227400000                     295301479
# ...
